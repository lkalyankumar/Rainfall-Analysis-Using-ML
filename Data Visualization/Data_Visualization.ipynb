# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('datarain.csv')
data.head()
# Out:
#                  SUBDIVISION         YEAR        JAN        FEB         MAR  \
# 0  ANDAMAN & NICOBAR ISLANDS  1958.918182  52.637273  27.994545   31.742894
# 1          ARUNACHAL PRADESH  1965.824742  47.005746  90.402117  150.925963
# 2          ASSAM & MEGHALAYA  1958.000000  16.974783  31.441739   79.026957
# 3                      BIHAR  1958.000000  13.386087  14.393913   10.124348
# 4               CHHATTISGARH  1958.000000  14.206957  19.259130   15.266957
#
#           APR         MAY         JUN         JUL         AUG         SEP  \
# 0   71.694135  354.590413  467.192444  399.082079  398.051154  432.878962
# 1  263.836082  358.522680  643.073551  690.964065  495.229897  432.134021
# 2  203.115652  341.539130  510.161739  495.102609  404.593043  310.734783
# 3   16.918261   53.081739  174.315652  324.441739  299.643478  217.384348
# 4   16.773043   21.048696  198.266087  398.577391  389.873043  217.780000
#
# ...

# %%
x=data.iloc[:,:1].values
y=data.iloc[:,14].values
x
# Out:
# array([['ANDAMAN & NICOBAR ISLANDS'],
#        ['ARUNACHAL PRADESH'],
#        ['ASSAM & MEGHALAYA'],
#        ['BIHAR'],
#        ['CHHATTISGARH'],
#        ['COASTAL ANDHRA PRADESH'],
#        ['COASTAL KARNATAKA'],
#        ['EAST MADHYA PRADESH'],
#        ['EAST RAJASTHAN'],
#        ['EAST UTTAR PRADESH'],
#        ['GANGETIC WEST BENGAL'],
#        ['GUJARAT REGION'],
#        ['HARYANA DELHI & CHANDIGARH'],
#        ['HIMACHAL PRADESH'],
#        ['JAMMU & KASHMIR'],
#        ['JHARKHAND'],
#        ['KERALA'],
#        ['KONKAN & GOA'],
#        ['LAKSHADWEEP'],
#        ['MADHYA MAHARASHTRA'],
#        ['MATATHWADA'],
#        ['NAGA MANI MIZO TRIPURA'],
#        ['NORTH INTERIOR KARNATAKA'],
#        ['ORISSA'],
#        ['PUNJAB'],
#        ['RAYALSEEMA'],
#        ['SAURASHTRA & KUTCH'],
#        ['SOUTH INTERIOR KARNATAKA'],
#        ['SUB HIMALAYAN WEST BENGAL & SIKKIM'],
#        ['TAMIL NADU'],
#        ['TELANGANA'],
#        ['UTTARAKHAND'],
#        ['VIDARBHA'],
# ...

# %%
data.corr()
# Out:
#              YEAR       JAN       FEB       MAR       APR       MAY       JUN  \
# YEAR     1.000000  0.244237  0.438496  0.576181  0.632525  0.485257  0.350582
# JAN      0.244237  1.000000  0.924222  0.774185  0.361995  0.240220 -0.050090
# FEB      0.438496  0.924222  1.000000  0.930344  0.573309  0.336101  0.059123
# MAR      0.576181  0.774185  0.930344  1.000000  0.822699  0.582895  0.275958
# APR      0.632525  0.361995  0.573309  0.822699  1.000000  0.881998  0.573962
# MAY      0.485257  0.240220  0.336101  0.582895  0.881998  1.000000  0.710813
# JUN      0.350582 -0.050090  0.059123  0.275958  0.573962  0.710813  1.000000
# JUL      0.246497 -0.078925  0.028045  0.164035  0.343132  0.429049  0.920171
# AUG      0.239678  0.014657  0.121900  0.232043  0.379587  0.475600  0.875319
# SEP      0.444645  0.045189  0.153439  0.340656  0.610761  0.775735  0.833761
# OCT      0.273297  0.004050  0.002256  0.205388  0.553274  0.770860  0.693490
# ...

# %%
sns.heatmap(data.corr())

# %%
X=data.iloc[:,2].values
Y=data.iloc[:,14].values
X
# Out:
# array([ 52.63727273,  47.00574557,  16.97478261,  13.38608696,
#         14.20695652,   7.48347826,   2.08571583,  19.40173913,
#          6.4226087 ,  16.01217391,  12.59565217,   1.78608696,
#         16.88956522,  84.18956522, 102.03043478,  17.62173913,
#         12.24695652,   1.2626087 ,  27.34486526,   3.05478261,
#          5.00086957,  14.02521739,   3.01304348,  12.32956522,
#         25.24608696,   9.86782609,   1.13913043,   2.92869565,
#         14.08347826,  23.81913043,   7.7026087 ,  53.7973913 ,
#         10.56347826,   9.24173913,   3.32782609,  17.66608696])

# %%
sns.jointplot(x=X, y=Y, kind="hex", color="k");

# %%
d3= sns.jointplot("YEAR","ANNUAL", data=data, kind="hex",color='#00FF00')

# %%
sns.clustermap(data.corr(), center=0, cmap="vlag",
               linewidths=.75, figsize=(8, 8))

# %%
fig = plt.figure(figsize=(25, 15))
ax3 = plt.xticks(rotation=90)
ax3 = sns.barplot(x='SUBDIVISION', y='ANNUAL', data=data.sort_values('ANNUAL'))
ax3 = plt.title('Total Rainfall in all States and UT in increasing order',fontsize=40)

# %%
data1= data.drop('SUBDIVISION', axis=1)
data1 = data.T
data1.columns = data1.iloc[0]
data1.drop(data1.index[0],inplace=True)

# %%
monthly_total_rainfall = data1.head(12)
seasonal_total_rainfall = data1.tail(4)

# %%
plt.style.use('seaborn-whitegrid')
fig = plt.figure(figsize=(100,100))

for i in range(35):
    plt.subplot(7, 5, i+1)
    t = monthly_total_rainfall[monthly_total_rainfall.columns[i]].plot.bar()
    t.set_title("Monthly Rainfall for " + str(monthly_total_rainfall.columns[i]))
plt.show()

# %%
plt.style.use('seaborn-whitegrid')
fig = plt.figure(figsize=(100,100))

for i in range(35):
    plt.subplot(7, 5, i+1)
    t = seasonal_total_rainfall[seasonal_total_rainfall.columns[i]].plot.bar()
    
    t.set_title("Seasonal Rainfall for " +str(seasonal_total_rainfall.columns[i]))
plt.show()

# %%
ax3 = plt.xticks(rotation=90)
ax3 = sns.barplot(x='YEAR', y='ANNUAL', data=data)
ax3 = plt.title('Total Rainfall in  all years')

# %%
ax = plt.xticks(rotation=90)
ax = sns.barplot(x='SUBDIVISION', y='ANNUAL', data=data,ci=None)

# %%
ax = plt.xticks(rotation=90)
ax = sns.pointplot(x='SUBDIVISION', y='ANNUAL', data=data,ci=None)
